# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
#
# For this assignment we will explore and cluster the neighborhoods in Toronto.

# %% [markdown]
# ## Step 1.  Scrape the data from Wikipedia

# %%
#import necessary packages
import pandas as pd
import html5lib
import lxml
import requests
import bs4 as bs
from bs4 import BeautifulSoup

# !pip install lxml


#define the URL we will be scraping
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(website_url,'lxml')

#find table with postal code info
My_table = soup.find('table',{'class':'wikitable sortable'})

#parse table html
rows = My_table.findAll('tr')
parsed_table_data = []

for row in rows:
    children = row.findChildren(recursive=False)
    row_text = []
    for child in children:
        clean_text = child.text
        #This is to discard reference/citation links
        clean_text = clean_text.split('&#91;')[0]
        #This is to clean the header row of the sort icons
        clean_text = clean_text.split('&#160;')[-1]
        clean_text = clean_text.strip()
        row_text.append(clean_text)
    parsed_table_data.append(row_text)
    
#put the table data into a dataframe
df = pd.DataFrame(parsed_table_data[1:],columns=parsed_table_data[0])
# Out:
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)

# %% [markdown]
# ## Clean up the dataframe data

# %%
#if neighbourhood Not Assigned, then neighbourhood=borough
df['Neighbourhood'] = df['Neighbourhood'].replace("Not assigned", df['Borough'])

#remove rows with Borough not assigned
df2 = df[df.Borough != "Not assigned"]

#merge rows with the same post code
df3=df2.groupby(['Postcode','Borough'])['Neighbourhood'].apply(','.join).reset_index()
df3.head()
# Out:
#   Postcode      Borough                         Neighbourhood
# 0      M1B  Scarborough                         Rouge,Malvern
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill
# 3      M1G  Scarborough                                Woburn
# 4      M1H  Scarborough                             Cedarbrae

# %%
df3.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Populate Longitudes and Latitudes into Dataframe

# %%
#download geospatial coordinates
# !wget -O Geospatial_coordinates.csv https://cocl.us/Geospatial_data/Geospatial_coordinates.csv

#read CSV into dataframe
GCdf = pd.read_csv('Geospatial_coordinates.csv')

#merge coordinate dataframe with neighborhood dataframe
GCdf.rename(columns={'Postal Code': 'Postcode'}, inplace=True)
result = pd.merge(df3,
                 GCdf[['Postcode', 'Latitude', 'Longitude']],
                 on='Postcode')
result
# Out:
# --2019-08-18 19:38:06--  https://cocl.us/Geospatial_data/Geospatial_coordinates.csv
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-08-18 19:38:07--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-08-18 19:38:08--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-08-18 19:38:08--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.211, 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!nEmE71OiibQMpbLtRO2sxb1kvQpVatTAZ6VggCeBJsTbLG_nJmmHeHgb9NmfNYQ4DgJPIbGO-EUj8xpjqJoa4CQMvPFaSE2SX7VJYSucEfwMn-DXp0VH4Rr_he2rRjKWtp1MlKlkdxbeeD6pi-jJnb1y7wTTTHbXXHyDr80OFEt8fLta1WJwebamdSd8YYgkQ_7h6uJ5l8B_9nKwMmBVU6G7R3fmqMCdaZYGjwS_KEGp-ZnArBONYuSxn9e1q8aGFrwIz5EpkIu9Qpgf_DQr-z10yYxtbp_ES1eLIrDW3bB5IzqLIdsbgKRsbPAiPFSUxi_jjAUPtVfp_dAL1w6RuShHde-tZwhXYo933zfCNCWXOceQ2flKc-hQjBLl-gBr3HsagBuxQkF-o28mrBLSF5BJab7eAPfv5hIYWMETp9w3y7FLJ8m486P-C2ZYSJgkpQDQCV7vq18XjLrzFUw8lt7ZNfd05XDcrhT6veZeRvDOlJ4O21lpZWn8ghGoDgAl5d2A6KB8vhz6wxjOoGVsitG4ZlQcPdMwEIvYIuxysKN84DtAMNdfMr7Zx7lq_yZZCDCY2Mbx86pX2g3AAeiIymITpTrrGTrSqCzNQ1DLH_97BDly37s-ledgd7xfTqJ2MZaaBl4lZ3aaOrrcQD4sUFTSwWQna_yWnZX4ruxzZZKoPkPcO-Gu9vF-Jxj-BBg195k3moqZnPHSH1mJGOpvdtOibnWc94i6lTJM6upv7MjojL74jKVvX5qUxVZPK3bm-AukGF-vmA1SYNj6VS18s7m0fvSI3OZkeDqax_51GtokuEjVc9OyN-ug0uvL36bhrDMiZb0rDqG-W27XtQJSA3oPIUxHuYqiJj9pnL50DT9AnT7r92-psRU5iE21eqDMdmfh-NzAnkMG801U_Y1InJMz2TUzDsFRkgJ1ZAiMiVjYZ0EyS-jQvgU81z1NREtZSkC0w3FpZreOQT30i6kSvnaUixOErekJcLXdUKygbbZtZEA30zteOAZ4ByARBcM9T3AJbF22x21-cz12miAck_dgZfv3YP9ywIVEy6F8Tj4rnvOhp1qqQJWxZFAP_pMXuCKAYQvoYfpaKJD2yepzGKEf6SFclEz6irpxA6DrY9ePMQOQgdcYlyHdyXyUlhQpkJMRZ4of9tonqWEj9tQyTCbHqBn7xpwgpWgnaaqO28temkDAyvfP_8hZRLyTii21AlAfKDwWYP5Ybt8_TwuhJxIrmBVbqTUtt_vLmn9WNyJF9XkzsFlhQWbiaE9D2vzcAyWWFbPj-7WpV_HvkWJYoH9mzikSn5lPLEpzZhZSJZGvf6y6W26qbx5_EHpaKmUTeRBkziIZ1lNhYgawZmturY7dPXJcD2pB41fkcnk1r1H0u8oRZJB8yw../download [following]
# --2019-08-18 19:38:08--  https://public.boxcloud.com/d/1/b1!nEmE71OiibQMpbLtRO2sxb1kvQpVatTAZ6VggCeBJsTbLG_nJmmHeHgb9NmfNYQ4DgJPIbGO-EUj8xpjqJoa4CQMvPFaSE2SX7VJYSucEfwMn-DXp0VH4Rr_he2rRjKWtp1MlKlkdxbeeD6pi-jJnb1y7wTTTHbXXHyDr80OFEt8fLta1WJwebamdSd8YYgkQ_7h6uJ5l8B_9nKwMmBVU6G7R3fmqMCdaZYGjwS_KEGp-ZnArBONYuSxn9e1q8aGFrwIz5EpkIu9Qpgf_DQr-z10yYxtbp_ES1eLIrDW3bB5IzqLIdsbgKRsbPAiPFSUxi_jjAUPtVfp_dAL1w6RuShHde-tZwhXYo933zfCNCWXOceQ2flKc-hQjBLl-gBr3HsagBuxQkF-o28mrBLSF5BJab7eAPfv5hIYWMETp9w3y7FLJ8m486P-C2ZYSJgkpQDQCV7vq18XjLrzFUw8lt7ZNfd05XDcrhT6veZeRvDOlJ4O21lpZWn8ghGoDgAl5d2A6KB8vhz6wxjOoGVsitG4ZlQcPdMwEIvYIuxysKN84DtAMNdfMr7Zx7lq_yZZCDCY2Mbx86pX2g3AAeiIymITpTrrGTrSqCzNQ1DLH_97BDly37s-ledgd7xfTqJ2MZaaBl4lZ3aaOrrcQD4sUFTSwWQna_yWnZX4ruxzZZKoPkPcO-Gu9vF-Jxj-BBg195k3moqZnPHSH1mJGOpvdtOibnWc94i6lTJM6upv7MjojL74jKVvX5qUxVZPK3bm-AukGF-vmA1SYNj6VS18s7m0fvSI3OZkeDqax_51GtokuEjVc9OyN-ug0uvL36bhrDMiZb0rDqG-W27XtQJSA3oPIUxHuYqiJj9pnL50DT9AnT7r92-psRU5iE21eqDMdmfh-NzAnkMG801U_Y1InJMz2TUzDsFRkgJ1ZAiMiVjYZ0EyS-jQvgU81z1NREtZSkC0w3FpZreOQT30i6kSvnaUixOErekJcLXdUKygbbZtZEA30zteOAZ4ByARBcM9T3AJbF22x21-cz12miAck_dgZfv3YP9ywIVEy6F8Tj4rnvOhp1qqQJWxZFAP_pMXuCKAYQvoYfpaKJD2yepzGKEf6SFclEz6irpxA6DrY9ePMQOQgdcYlyHdyXyUlhQpkJMRZ4of9tonqWEj9tQyTCbHqBn7xpwgpWgnaaqO28temkDAyvfP_8hZRLyTii21AlAfKDwWYP5Ybt8_TwuhJxIrmBVbqTUtt_vLmn9WNyJF9XkzsFlhQWbiaE9D2vzcAyWWFbPj-7WpV_HvkWJYoH9mzikSn5lPLEpzZhZSJZGvf6y6W26qbx5_EHpaKmUTeRBkziIZ1lNhYgawZmturY7dPXJcD2pB41fkcnk1r1H0u8oRZJB8yw../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.25.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.25.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_coordinates.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2019-08-18 19:38:09 (339 MB/s) - ‘Geospatial_coordinates.csv’ saved [2891/2891]
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                        Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                    Maryvale,Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             Silver Hills,York Mills  43.757490 -79.374714
# 21                              Newtonbrook,Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 79                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        The Junction North,Runnymede  43.673185 -79.487262
# 82                        High Park,The Junction South  43.661608 -79.464763
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89                               Alderwood,Long Branch  43.602414 -79.543484
# 90         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# ## Map our Neighbourhoods

# %%
# import dependencies for mapping
import numpy as np 
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
# find latitude and longitude of Toronto for centering map
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(result['Latitude'], result['Longitude'], result['Borough'], result['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore Neighborhood Venues using Foursquare Data

# %%
# define foursquare credentials and version
CLIENT_ID = 'G4IPBDM45EYRDR2IU0LXLQNFOSASQAWUSE412WNUOVSWADQ5' # your Foursquare ID
CLIENT_SECRET = 'KRSH4OM11NNCWEU5VHCJNRXTT4YLR3FJJHJT42SBVABGQCXQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: G4IPBDM45EYRDR2IU0LXLQNFOSASQAWUSE412WNUOVSWADQ5
# CLIENT_SECRET:KRSH4OM11NNCWEU5VHCJNRXTT4YLR3FJJHJT42SBVABGQCXQ

# %%
# Function which returns venues within a radius of a certain location
LIMIT = 100 # limit of number of venues returned by Foursquare API

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# get nearby venues for all neighborhoods
toronto_venues = getNearbyVenues(names=result['Neighbourhood'],
                                   latitudes=result['Latitude'],
                                   longitudes=result['Longitude']
                                  )
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# Rouge,Malvern
# Highland Creek,Rouge Hill,Port Union
# Guildwood,Morningside,West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park,Ionview,Kennedy Park
# Clairlea,Golden Mile,Oakridge
# Cliffcrest,Cliffside,Scarborough Village West
# Birch Cliff,Cliffside West
# Dorset Park,Scarborough Town Centre,Wexford Heights
# Maryvale,Wexford
# Agincourt
# Clarks Corners,Sullivan,Tam O'Shanter
# Agincourt North,L'Amoreaux East,Milliken,Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview,Henry Farm,Oriole
# Bayview Village
# Silver Hills,York Mills
# Newtonbrook,Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park,Don Mills South
# Bathurst Manor,Downsview North,Wilson Heights
# Northwood Park,York University
# CFB Toronto,Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens,Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West,Riverdale
# The Beaches West,India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park,Summerhill East
# Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West
# Rosedale
# Cabbagetown,St. James Town
# Church and Wellesley
# Harbourfront,Regent Park
# Ryerson,Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide,King,Richmond
# Harbourfront East,Toronto Islands,Union Station
# Design Exchange,Toronto Dominion Centre
# Commerce Court,Victoria Hotel
# Bedford Park,Lawrence Manor East
# Roselawn
# Forest Hill North,Forest Hill West
# The Annex,North Midtown,Yorkville
# Harbord,University of Toronto
# Chinatown,Grange Park,Kensington Market
# CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place,Underground city
# Lawrence Heights,Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village,Dufferin
# Little Portugal,Trinity
# Brockton,Exhibition Place,Parkdale Village
# Downsview,North Park,Upwood Park
# Del Ray,Keelesdale,Mount Dennis,Silverthorn
# The Junction North,Runnymede
# High Park,The Junction South
# Parkdale,Roncesvalles
# Runnymede,Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores,Mimico South,New Toronto
# Alderwood,Long Branch
# The Kingsway,Montgomery Road,Old Mill North
# Humber Bay,King's Mill Park,Kingsway Park South East,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea
# Kingsway Park South West,Mimico NW,The Queensway West,Royal York South West,South of Bloor
# Islington Avenue
# Cloverdale,Islington,Martin Grove,Princess Gardens,West Deane Park
# Bloordale Gardens,Eringate,Markland Wood,Old Burnhamthorpe
# Humber Summit
# Emery,Humberlea
# Weston
# Westmount
# Kingsview Village,Martin Grove Gardens,Richview Gardens,St. Phillips
# Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown
# Northwest
# (2237, 7)
#                            Neighborhood  Neighborhood Latitude  \
# 0                         Rouge,Malvern              43.806686
# 1  Highland Creek,Rouge Hill,Port Union              43.784535
# 2  Highland Creek,Rouge Hill,Port Union              43.784535
# 3       Guildwood,Morningside,West Hill              43.763573
# 4       Guildwood,Morningside,West Hill              43.763573
#
#    Neighborhood Longitude                            Venue  Venue Latitude  \
# 0              -79.194353                          Wendy's       43.807448
# 1              -79.160497            Royal Canadian Legion       43.782533
# 2              -79.160497        Affordable Toronto Movers       43.787919
# 3              -79.188711  Swiss Chalet Rotisserie & Grill       43.767697
# 4              -79.188711                G & G Electronics       43.765309
#
#    Venue Longitude        Venue Category
# 0       -79.199056  Fast Food Restaurant
# 1       -79.163085                   Bar
# 2       -79.162977         Moving Target
# 3       -79.189914           Pizza Place
# 4       -79.191537     Electronics Store

# %%
#how many venues were returned per neighborhood?
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Adelaide,King,Richmond                                                100
# Agincourt                                                               5
# Agincourt North,L'Amoreaux East,Milliken,Steele...                      2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...                     10
# Alderwood,Long Branch                                                  10
# Bathurst Manor,Downsview North,Wilson Heights                          19
# Bayview Village                                                         4
# Bedford Park,Lawrence Manor East                                       22
# Berczy Park                                                            57
# Birch Cliff,Cliffside West                                              4
# Bloordale Gardens,Eringate,Markland Wood,Old Bu...                      7
# Brockton,Exhibition Place,Parkdale Village                             22
# Business Reply Mail Processing Centre 969 Eastern                      15
# CFB Toronto,Downsview East                                              3
# CN Tower,Bathurst Quay,Island airport,Harbourfr...                     16
# Cabbagetown,St. James Town                                             50
# Caledonia-Fairbanks                                                     5
# Canada Post Gateway Processing Centre                                  11
# Cedarbrae                                                               7
# Central Bay Street                                                     85
# Chinatown,Grange Park,Kensington Market                               100
# Christie                                                               16
# Church and Wellesley                                                   86
# Clairlea,Golden Mile,Oakridge                                           8
# Clarks Corners,Sullivan,Tam O'Shanter                                  11
# Cliffcrest,Cliffside,Scarborough Village West                           3
# Cloverdale,Islington,Martin Grove,Princess Gard...                      1
# Commerce Court,Victoria Hotel                                         100
# Davisville                                                             35
# Davisville North                                                        9
# ...                                                                   ...
# Northwood Park,York University                                          5
# Parkdale,Roncesvalles                                                  15
# Parkwoods                                                               3
# Queen's Park                                                           38
# Rosedale                                                                5
# Roselawn                                                                1
# Rouge,Malvern                                                           1
# Runnymede,Swansea                                                      35
# Ryerson,Garden District                                               100
# Scarborough Village                                                     2
# Silver Hills,York Mills                                                 1
# St. James Town                                                        100
# Stn A PO Boxes 25 The Esplanade                                        96
# Studio District                                                        40
# The Annex,North Midtown,Yorkville                                      23
# The Beaches                                                             4
# The Beaches West,India Bazaar                                          20
# The Danforth West,Riverdale                                            42
# The Junction North,Runnymede                                            4
# The Kingsway,Montgomery Road,Old Mill North                             2
# Thorncliffe Park                                                       18
# Victoria Village                                                        5
# Westmount                                                               7
# Weston                                                                  1
# Willowdale South                                                       36
# Willowdale West                                                         6
# Woburn                                                                  3
# Woodbine Gardens,Parkview Hill                                         10
# Woodbine Heights                                                       10
# York Mills West                                                         3
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Adelaide,King,Richmond                                                 100
# Agincourt                                                                5
# Agincourt North,L'Amoreaux East,Milliken,Steele...                       2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...                      10
# Alderwood,Long Branch                                                   10
# Bathurst Manor,Downsview North,Wilson Heights                           19
# Bayview Village                                                          4
# Bedford Park,Lawrence Manor East                                        22
# Berczy Park                                                             57
# Birch Cliff,Cliffside West                                               4
# Bloordale Gardens,Eringate,Markland Wood,Old Bu...                       7
# Brockton,Exhibition Place,Parkdale Village                              22
# Business Reply Mail Processing Centre 969 Eastern                       15
# CFB Toronto,Downsview East                                               3
# CN Tower,Bathurst Quay,Island airport,Harbourfr...                      16
# Cabbagetown,St. James Town                                              50
# Caledonia-Fairbanks                                                      5
# Canada Post Gateway Processing Centre                                   11
# Cedarbrae                                                                7
# Central Bay Street                                                      85
# Chinatown,Grange Park,Kensington Market                                100
# Christie                                                                16
# Church and Wellesley                                                    86
# Clairlea,Golden Mile,Oakridge                                            8
# Clarks Corners,Sullivan,Tam O'Shanter                                   11
# Cliffcrest,Cliffside,Scarborough Village West                            3
# Cloverdale,Islington,Martin Grove,Princess Gard...                       1
# Commerce Court,Victoria Hotel                                          100
# Davisville                                                              35
# Davisville North                                                         9
# ...                                                                    ...
# Northwood Park,York University                                           5
# Parkdale,Roncesvalles                                                   15
# Parkwoods                                                                3
# Queen's Park                                                            38
# Rosedale                                                                 5
# Roselawn                                                                 1
# Rouge,Malvern                                                            1
# Runnymede,Swansea                                                       35
# Ryerson,Garden District                                                100
# Scarborough Village                                                      2
# Silver Hills,York Mills                                                  1
# St. James Town                                                         100
# Stn A PO Boxes 25 The Esplanade                                         96
# Studio District                                                         40
# The Annex,North Midtown,Yorkville                                       23
# The Beaches                                                              4
# The Beaches West,India Bazaar                                           20
# The Danforth West,Riverdale                                             42
# The Junction North,Runnymede                                             4
# The Kingsway,Montgomery Road,Old Mill North                              2
# Thorncliffe Park                                                        18
# Victoria Village                                                         5
# Westmount                                                                7
# Weston                                                                   1
# Willowdale South                                                        36
# Willowdale West                                                          6
# Woburn                                                                   3
# Woodbine Gardens,Parkview Hill                                          10
# Woodbine Heights                                                        10
# York Mills West                                                          3
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Adelaide,King,Richmond                                100             100
# Agincourt                                               5               5
# Agincourt North,L'Amoreaux East,Milliken,Steele...      2               2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...     10              10
# Alderwood,Long Branch                                  10              10
# Bathurst Manor,Downsview North,Wilson Heights          19              19
# Bayview Village                                         4               4
# Bedford Park,Lawrence Manor East                       22              22
# Berczy Park                                            57              57
# Birch Cliff,Cliffside West                              4               4
# Bloordale Gardens,Eringate,Markland Wood,Old Bu...      7               7
# Brockton,Exhibition Place,Parkdale Village             22              22
# Business Reply Mail Processing Centre 969 Eastern      15              15
# CFB Toronto,Downsview East                              3               3
# CN Tower,Bathurst Quay,Island airport,Harbourfr...     16              16
# Cabbagetown,St. James Town                             50              50
# Caledonia-Fairbanks                                     5               5
# Canada Post Gateway Processing Centre                  11              11
# Cedarbrae                                               7               7
# Central Bay Street                                     85              85
# Chinatown,Grange Park,Kensington Market               100             100
# Christie                                               16              16
# Church and Wellesley                                   86              86
# Clairlea,Golden Mile,Oakridge                           8               8
# Clarks Corners,Sullivan,Tam O'Shanter                  11              11
# Cliffcrest,Cliffside,Scarborough Village West           3               3
# Cloverdale,Islington,Martin Grove,Princess Gard...      1               1
# Commerce Court,Victoria Hotel                         100             100
# Davisville                                             35              35
# Davisville North                                        9               9
# ...                                                   ...             ...
# Northwood Park,York University                          5               5
# Parkdale,Roncesvalles                                  15              15
# Parkwoods                                               3               3
# Queen's Park                                           38              38
# Rosedale                                                5               5
# Roselawn                                                1               1
# Rouge,Malvern                                           1               1
# Runnymede,Swansea                                      35              35
# Ryerson,Garden District                               100             100
# Scarborough Village                                     2               2
# Silver Hills,York Mills                                 1               1
# St. James Town                                        100             100
# Stn A PO Boxes 25 The Esplanade                        96              96
# Studio District                                        40              40
# The Annex,North Midtown,Yorkville                      23              23
# The Beaches                                             4               4
# The Beaches West,India Bazaar                          20              20
# The Danforth West,Riverdale                            42              42
# The Junction North,Runnymede                            4               4
# The Kingsway,Montgomery Road,Old Mill North             2               2
# Thorncliffe Park                                       18              18
# Victoria Village                                        5               5
# Westmount                                               7               7
# Weston                                                  1               1
# Willowdale South                                       36              36
# Willowdale West                                         6               6
# Woburn                                                  3               3
# Woodbine Gardens,Parkview Hill                         10              10
# Woodbine Heights                                       10              10
# York Mills West                                         3               3
#
#                                                     Venue Longitude  \
# Neighborhood
# Adelaide,King,Richmond                                          100
# Agincourt                                                         5
# Agincourt North,L'Amoreaux East,Milliken,Steele...                2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...               10
# Alderwood,Long Branch                                            10
# Bathurst Manor,Downsview North,Wilson Heights                    19
# Bayview Village                                                   4
# Bedford Park,Lawrence Manor East                                 22
# Berczy Park                                                      57
# Birch Cliff,Cliffside West                                        4
# Bloordale Gardens,Eringate,Markland Wood,Old Bu...                7
# Brockton,Exhibition Place,Parkdale Village                       22
# Business Reply Mail Processing Centre 969 Eastern                15
# CFB Toronto,Downsview East                                        3
# CN Tower,Bathurst Quay,Island airport,Harbourfr...               16
# Cabbagetown,St. James Town                                       50
# Caledonia-Fairbanks                                               5
# Canada Post Gateway Processing Centre                            11
# Cedarbrae                                                         7
# Central Bay Street                                               85
# Chinatown,Grange Park,Kensington Market                         100
# Christie                                                         16
# Church and Wellesley                                             86
# Clairlea,Golden Mile,Oakridge                                     8
# Clarks Corners,Sullivan,Tam O'Shanter                            11
# Cliffcrest,Cliffside,Scarborough Village West                     3
# Cloverdale,Islington,Martin Grove,Princess Gard...                1
# Commerce Court,Victoria Hotel                                   100
# Davisville                                                       35
# Davisville North                                                  9
# ...                                                             ...
# Northwood Park,York University                                    5
# Parkdale,Roncesvalles                                            15
# Parkwoods                                                         3
# Queen's Park                                                     38
# Rosedale                                                          5
# Roselawn                                                          1
# Rouge,Malvern                                                     1
# Runnymede,Swansea                                                35
# Ryerson,Garden District                                         100
# Scarborough Village                                               2
# Silver Hills,York Mills                                           1
# St. James Town                                                  100
# Stn A PO Boxes 25 The Esplanade                                  96
# Studio District                                                  40
# The Annex,North Midtown,Yorkville                                23
# The Beaches                                                       4
# The Beaches West,India Bazaar                                    20
# The Danforth West,Riverdale                                      42
# The Junction North,Runnymede                                      4
# The Kingsway,Montgomery Road,Old Mill North                       2
# Thorncliffe Park                                                 18
# Victoria Village                                                  5
# Westmount                                                         7
# Weston                                                            1
# Willowdale South                                                 36
# Willowdale West                                                   6
# Woburn                                                            3
# Woodbine Gardens,Parkview Hill                                   10
# Woodbine Heights                                                 10
# York Mills West                                                   3
#
#                                                     Venue Category
# Neighborhood
# Adelaide,King,Richmond                                         100
# Agincourt                                                        5
# Agincourt North,L'Amoreaux East,Milliken,Steele...               2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...              10
# Alderwood,Long Branch                                           10
# Bathurst Manor,Downsview North,Wilson Heights                   19
# Bayview Village                                                  4
# Bedford Park,Lawrence Manor East                                22
# Berczy Park                                                     57
# Birch Cliff,Cliffside West                                       4
# Bloordale Gardens,Eringate,Markland Wood,Old Bu...               7
# Brockton,Exhibition Place,Parkdale Village                      22
# Business Reply Mail Processing Centre 969 Eastern               15
# CFB Toronto,Downsview East                                       3
# CN Tower,Bathurst Quay,Island airport,Harbourfr...              16
# Cabbagetown,St. James Town                                      50
# Caledonia-Fairbanks                                              5
# Canada Post Gateway Processing Centre                           11
# Cedarbrae                                                        7
# Central Bay Street                                              85
# Chinatown,Grange Park,Kensington Market                        100
# Christie                                                        16
# Church and Wellesley                                            86
# Clairlea,Golden Mile,Oakridge                                    8
# Clarks Corners,Sullivan,Tam O'Shanter                           11
# Cliffcrest,Cliffside,Scarborough Village West                    3
# Cloverdale,Islington,Martin Grove,Princess Gard...               1
# Commerce Court,Victoria Hotel                                  100
# Davisville                                                      35
# Davisville North                                                 9
# ...                                                            ...
# Northwood Park,York University                                   5
# Parkdale,Roncesvalles                                           15
# Parkwoods                                                        3
# Queen's Park                                                    38
# Rosedale                                                         5
# Roselawn                                                         1
# Rouge,Malvern                                                    1
# Runnymede,Swansea                                               35
# Ryerson,Garden District                                        100
# Scarborough Village                                              2
# Silver Hills,York Mills                                          1
# St. James Town                                                 100
# Stn A PO Boxes 25 The Esplanade                                 96
# Studio District                                                 40
# The Annex,North Midtown,Yorkville                               23
# The Beaches                                                      4
# The Beaches West,India Bazaar                                   20
# The Danforth West,Riverdale                                     42
# The Junction North,Runnymede                                     4
# The Kingsway,Montgomery Road,Old Mill North                      2
# Thorncliffe Park                                                18
# Victoria Village                                                 5
# Westmount                                                        7
# Weston                                                           1
# Willowdale South                                                36
# Willowdale West                                                  6
# Woburn                                                           3
# Woodbine Gardens,Parkview Hill                                  10
# Woodbine Heights                                                10
# York Mills West                                                  3
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Find the top 5 types of venues for each neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# group by neighborhood and find the mean frequency occurrance of each type of venue
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

#function to return most common venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# display the top 10 venues for each neighborhood.
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                             Adelaide,King,Richmond           Coffee Shop
# 1                                          Agincourt                Lounge
# 2  Agincourt North,L'Amoreaux East,Milliken,Steel...                  Park
# 3  Albion Gardens,Beaumond Heights,Humbergate,Jam...         Grocery Store
# 4                              Alderwood,Long Branch           Pizza Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café       Thai Restaurant            Steakhouse
# 1        Breakfast Spot          Skating Rink    Chinese Restaurant
# 2            Playground   Dumpling Restaurant        Discount Store
# 3            Beer Store        Sandwich Place           Coffee Shop
# 4                   Pub          Skating Rink                   Gym
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                   Bar            Restaurant                   Gym
# 1        Sandwich Place         Women's Store             Drugstore
# 2              Dive Bar               Dog Run      Doner Restaurant
# 3           Pizza Place              Pharmacy   Fried Chicken Joint
# 4           Coffee Shop              Pharmacy    Athletics & Sports
#
#   8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 0        Breakfast Spot                 Hotel          American Restaurant
# 1               Dog Run      Doner Restaurant                   Donut Shop
# 2            Donut Shop             Drugstore  Eastern European Restaurant
# 3           Video Store  Fast Food Restaurant          Empanada Restaurant
# 4                  Pool        Sandwich Place                      Dog Run

# %% [markdown]
# ## Cluster Neighborhoods

# %%
#run k-means to cluster neighborhoods into 5 clusters
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
#neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = result
toronto_merged.rename(columns={'Neighbourhood':'Neighborhood'}, inplace=True)


# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#   Postcode      Borough                          Neighborhood   Latitude  \
# 0      M1B  Scarborough                         Rouge,Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353             2.0  Fast Food Restaurant         Women's Store
# 1 -79.160497             0.0         Moving Target                   Bar
# 2 -79.188711             0.0     Electronics Store          Intersection
# 3 -79.216917             0.0           Coffee Shop     Korean Restaurant
# 4 -79.239476             0.0  Caribbean Restaurant      Hakka Restaurant
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Eastern European Restaurant              Dive Bar               Dog Run
# 1                Women's Store                 Diner              Dive Bar
# 2               Breakfast Spot   Rental Car Location           Pizza Place
# 3  Eastern European Restaurant              Dive Bar               Dog Run
# 4           Athletics & Sports                Bakery                  Bank
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0      Doner Restaurant            Donut Shop             Drugstore
# 1               Dog Run      Doner Restaurant            Donut Shop
# 2        Medical Center    Mexican Restaurant            Donut Shop
# 3      Doner Restaurant            Donut Shop             Drugstore
# 4       Thai Restaurant   Fried Chicken Joint             Drugstore
#
#   9th Most Common Venue 10th Most Common Venue
# 0   Dumpling Restaurant      Electronics Store
# 1             Drugstore    Dumpling Restaurant
# 2        Discount Store               Dive Bar
# 3   Dumpling Restaurant          Women's Store
# 4               Dog Run       Doner Restaurant

# %% [markdown]
# ## Map Clustered Neighborhoods

# %%
#drop rows with nan data
toronto_merged = toronto_merged.dropna(how='any',axis=0) 

toronto_merged
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# ..       ...               ...
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude  \
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                        Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                    Maryvale,Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             Silver Hills,York Mills  43.757490 -79.374714
# 21                              Newtonbrook,Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# 30                          CFB Toronto,Downsview East  43.737473 -79.464763
# ..                                                 ...        ...        ...
# 72                                           Glencairn  43.709577 -79.445073
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 79                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        The Junction North,Runnymede  43.673185 -79.487262
# 82                        High Park,The Junction South  43.661608 -79.464763
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89                               Alderwood,Long Branch  43.602414 -79.543484
# 90         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
#      Cluster Labels   1st Most Common Venue       2nd Most Common Venue  \
# 0               2.0    Fast Food Restaurant               Women's Store
# 1               0.0           Moving Target                         Bar
# 2               0.0       Electronics Store                Intersection
# 3               0.0             Coffee Shop           Korean Restaurant
# 4               0.0    Caribbean Restaurant            Hakka Restaurant
# 5               1.0              Playground           Convenience Store
# 6               0.0          Discount Store           Convenience Store
# 7               2.0                  Bakery        Fast Food Restaurant
# 8               0.0                   Motel         American Restaurant
# 9               0.0         College Stadium                Skating Rink
# 10              0.0       Indian Restaurant   Latin American Restaurant
# 11              0.0             Auto Garage   Middle Eastern Restaurant
# 12              0.0                  Lounge              Breakfast Spot
# 13              0.0             Pizza Place              Breakfast Spot
# 14              2.0                    Park                  Playground
# 15              0.0      Chinese Restaurant        Fast Food Restaurant
# 17              0.0             Golf Course                        Pool
# 18              0.0          Clothing Store                 Coffee Shop
# 19              0.0                    Café         Japanese Restaurant
# 20              2.0               Cafeteria               Women's Store
# 21              0.0                     Gym               Women's Store
# 22              0.0             Coffee Shop            Ramen Restaurant
# 23              2.0                    Park           Convenience Store
# 24              0.0             Coffee Shop              Discount Store
# 25              2.0    Fast Food Restaurant                        Park
# 26              0.0                    Café         Japanese Restaurant
# 27              0.0                     Gym                 Coffee Shop
# 28              0.0             Coffee Shop               Deli / Bodega
# 29              0.0      Falafel Restaurant              Massage Studio
# 30              2.0                    Park           Other Repair Shop
# ..              ...                     ...                         ...
# 72              2.0                    Park         Japanese Restaurant
# 73              0.0                   Field                Hockey Arena
# 74              2.0                    Park               Women's Store
# 75              0.0           Grocery Store                        Café
# 76              0.0             Supermarket                      Bakery
# 77              0.0                     Bar                 Coffee Shop
# 78              0.0             Coffee Shop                        Café
# 79              2.0                    Park  Construction & Landscaping
# 80              2.0    Fast Food Restaurant              Sandwich Place
# 81              0.0             Pizza Place           Convenience Store
# 82              0.0                    Café          Mexican Restaurant
# 83              0.0               Gift Shop              Breakfast Spot
# 84              0.0             Coffee Shop                        Café
# 85              0.0             Coffee Shop                         Gym
# 86              0.0                   Hotel                 Coffee Shop
# 87              0.0          Farmers Market               Garden Center
# 88              0.0            Liquor Store                 Pizza Place
# 89              0.0             Pizza Place                         Pub
# 90              2.0                    Park                       River
# 91              0.0                    Pool              Baseball Field
# 92              0.0          Hardware Store               Tanning Salon
# 94              4.0                    Bank               Women's Store
# 95              0.0       Convenience Store                    Pharmacy
# 96              0.0             Pizza Place         Empanada Restaurant
# 97              0.0  Furniture / Home Store              Baseball Field
# 98              1.0       Convenience Store               Women's Store
# 99              0.0             Pizza Place                Intersection
# 100             2.0                    Park                 Pizza Place
# 101             0.0           Grocery Store                  Beer Store
# 102             0.0     Rental Car Location                   Drugstore
#
#            3rd Most Common Venue        4th Most Common Venue  \
# 0    Eastern European Restaurant                     Dive Bar
# 1                  Women's Store                        Diner
# 2                 Breakfast Spot          Rental Car Location
# 3    Eastern European Restaurant                     Dive Bar
# 4             Athletics & Sports                       Bakery
# 5                  Women's Store  Eastern European Restaurant
# 6                    Bus Station             Department Store
# 7                   Soccer Field                Metro Station
# 8                          Diner               Discount Store
# 9          General Entertainment                         Café
# 10                   Gaming Cafe           Chinese Restaurant
# 11                    Smoke Shop                Shopping Mall
# 12                  Skating Rink           Chinese Restaurant
# 13                  Noodle House                         Bank
# 14           Dumpling Restaurant               Discount Store
# 15                Breakfast Spot                  Pizza Place
# 17          Fast Food Restaurant                      Dog Run
# 18          Fast Food Restaurant            Electronics Store
# 19            Chinese Restaurant                         Bank
# 20   Eastern European Restaurant                      Dog Run
# 21   Eastern European Restaurant                     Dive Bar
# 22                    Restaurant               Sandwich Place
# 23                          Bank                Women's Store
# 24                      Pharmacy                  Pizza Place
# 25             Food & Drink Shop  Eastern European Restaurant
# 26          Caribbean Restaurant         Gym / Fitness Center
# 27                    Beer Store               Clothing Store
# 28                   Bridal Shop         Fast Food Restaurant
# 29          Caribbean Restaurant                  Coffee Shop
# 30                       Airport  Eastern European Restaurant
# ..                           ...                          ...
# 72                        Bakery                          Pub
# 73                         Trail               Farmers Market
# 74                        Market         Fast Food Restaurant
# 75                          Park                  Coffee Shop
# 76                      Pharmacy                         Bank
# 77              Asian Restaurant            French Restaurant
# 78                Breakfast Spot        Performing Arts Venue
# 79                        Bakery             Basketball Court
# 80                    Restaurant                  Event Space
# 81                 Grocery Store                     Bus Line
# 82                     Bookstore          Arts & Crafts Store
# 83                     Bookstore           Italian Restaurant
# 84                   Pizza Place           Italian Restaurant
# 85                         Diner                         Park
# 86           American Restaurant         Gym / Fitness Center
# 87                          Park                  Pizza Place
# 88                    Restaurant                         Café
# 89                  Skating Rink                          Gym
# 90                    Comic Shop                        Diner
# 91                         Diner                     Dive Bar
# 92                   Social Club                 Burger Joint
# 94   Eastern European Restaurant                      Dog Run
# 95                   Pizza Place                 Liquor Store
# 96                 Women's Store          Dumpling Restaurant
# 97                 Women's Store          Filipino Restaurant
# 98             Electronics Store                      Dog Run
# 99                Discount Store           Chinese Restaurant
# 100            Mobile Phone Shop                    Drugstore
# 101               Sandwich Place                  Coffee Shop
# 102                Women's Store           Dim Sum Restaurant
#
#            5th Most Common Venue        6th Most Common Venue  \
# 0                        Dog Run             Doner Restaurant
# 1                       Dive Bar                      Dog Run
# 2                    Pizza Place               Medical Center
# 3                        Dog Run             Doner Restaurant
# 4                           Bank              Thai Restaurant
# 5                       Dive Bar                      Dog Run
# 6                    Coffee Shop  Eastern European Restaurant
# 7                       Bus Line                  Bus Station
# 8                       Dive Bar                      Dog Run
# 9           Ethiopian Restaurant                  Event Space
# 10        Thrift / Vintage Store       Furniture / Home Store
# 11                Sandwich Place                       Bakery
# 12                Sandwich Place                Women's Store
# 13            Chinese Restaurant              Thai Restaurant
# 14                      Dive Bar                      Dog Run
# 15                Sandwich Place                   Nail Salon
# 17      Mediterranean Restaurant                     Dive Bar
# 18                        Bakery             Asian Restaurant
# 19                      Dive Bar                      Dog Run
# 20              Doner Restaurant                   Donut Shop
# 21                       Dog Run             Doner Restaurant
# 22                   Pizza Place                         Café
# 23   Eastern European Restaurant                      Dog Run
# 24                 Grocery Store                      Butcher
# 25                      Dive Bar                      Dog Run
# 26           Dumpling Restaurant                     Dive Bar
# 27              Asian Restaurant           Italian Restaurant
# 28                Sandwich Place                   Restaurant
# 29                           Bar                Women's Store
# 30                      Dive Bar                      Dog Run
# ..                           ...                          ...
# 72                         Diner                     Dive Bar
# 73            Falafel Restaurant         Fast Food Restaurant
# 74    Construction & Landscaping                     Dive Bar
# 75                    Baby Store                        Diner
# 76                           Bar       Furniture / Home Store
# 77                          Café                   Restaurant
# 78        Furniture / Home Store            Convenience Store
# 79                Farmers Market           Falafel Restaurant
# 80          Ethiopian Restaurant          Empanada Restaurant
# 81                 Women's Store          Dumpling Restaurant
# 82          Fast Food Restaurant                  Flea Market
# 83                    Restaurant                          Bar
# 84              Sushi Restaurant                Grocery Store
# 85           Japanese Restaurant           Chinese Restaurant
# 86           Fried Chicken Joint    Middle Eastern Restaurant
# 87                    Restaurant                Burrito Place
# 88            Mexican Restaurant               Sandwich Place
# 89                   Coffee Shop                     Pharmacy
# 90                Farmers Market           Falafel Restaurant
# 91                       Dog Run             Doner Restaurant
# 92                Sandwich Place                Burrito Place
# 94              Doner Restaurant                   Donut Shop
# 95                    Beer Store                  Coffee Shop
# 96                Discount Store                     Dive Bar
# 97                       Dog Run             Doner Restaurant
# 98              Doner Restaurant                   Donut Shop
# 99                   Coffee Shop               Sandwich Place
# 100               Discount Store                     Dive Bar
# 101                  Pizza Place                     Pharmacy
# 102               Discount Store                     Dive Bar
#
#          7th Most Common Venue        8th Most Common Venue  \
# 0                   Donut Shop                    Drugstore
# 1             Doner Restaurant                   Donut Shop
# 2           Mexican Restaurant                   Donut Shop
# 3                   Donut Shop                    Drugstore
# 4          Fried Chicken Joint                    Drugstore
# 5             Doner Restaurant                   Donut Shop
# 6             Doner Restaurant                   Donut Shop
# 7                         Park              Coworking Space
# 8             Doner Restaurant                   Donut Shop
# 9          Empanada Restaurant            Electronics Store
# 10       Vietnamese Restaurant                    Pet Store
# 11              Breakfast Spot                     Creperie
# 12                   Drugstore                      Dog Run
# 13         Fried Chicken Joint           Italian Restaurant
# 14            Doner Restaurant                   Donut Shop
# 15                 Coffee Shop       Thrift / Vintage Store
# 17            Doner Restaurant                   Donut Shop
# 18                    Tea Room                   Food Court
# 19            Doner Restaurant                   Donut Shop
# 20                   Drugstore          Dumpling Restaurant
# 21                  Donut Shop                    Drugstore
# 22            Sushi Restaurant                    Juice Bar
# 23            Doner Restaurant                   Donut Shop
# 24                   Drugstore                     Dive Bar
# 25            Doner Restaurant                   Donut Shop
# 26                     Dog Run             Doner Restaurant
# 27                 Supermarket                   Restaurant
# 28                       Diner                         Bank
# 29         Dumpling Restaurant                      Dog Run
# 30            Doner Restaurant                   Donut Shop
# ..                         ...                          ...
# 72                     Dog Run             Doner Restaurant
# 73                 Event Space         Ethiopian Restaurant
# 74              Farmers Market                 Concert Hall
# 75          Italian Restaurant           Athletics & Sports
# 76   Middle Eastern Restaurant                         Café
# 77                 Pizza Place                 Cocktail Bar
# 78                   Pet Store                 Climbing Gym
# 79                 Event Space         Ethiopian Restaurant
# 80           Electronics Store  Eastern European Restaurant
# 81                    Dive Bar                      Dog Run
# 82   Cajun / Creole Restaurant                    Speakeasy
# 83               Movie Theater                 Dessert Shop
# 84          Falafel Restaurant                          Bar
# 85               Smoothie Shop           Seafood Restaurant
# 86    Mediterranean Restaurant                Burrito Place
# 87                     Brewery                   Skate Park
# 88                      Bakery          American Restaurant
# 89          Athletics & Sports                         Pool
# 90                 Event Space         Ethiopian Restaurant
# 91                  Donut Shop                    Drugstore
# 92                      Bakery              Supplement Shop
# 94                   Drugstore          Dumpling Restaurant
# 95                        Café                Women's Store
# 96                     Dog Run             Doner Restaurant
# 97                  Donut Shop                    Drugstore
# 98                   Drugstore          Dumpling Restaurant
# 99                  Donut Shop                        Diner
# 100                    Dog Run             Doner Restaurant
# 101        Fried Chicken Joint                  Video Store
# 102                    Dog Run             Doner Restaurant
#
#            9th Most Common Venue       10th Most Common Venue
# 0            Dumpling Restaurant            Electronics Store
# 1                      Drugstore          Dumpling Restaurant
# 2                 Discount Store                     Dive Bar
# 3            Dumpling Restaurant                Women's Store
# 4                        Dog Run             Doner Restaurant
# 5                      Drugstore          Dumpling Restaurant
# 6                      Drugstore          Dumpling Restaurant
# 7                       Creperie               Farmers Market
# 8                      Drugstore                Women's Store
# 9    Eastern European Restaurant                        Diner
# 10              Doner Restaurant                  Event Space
# 11              Cuban Restaurant   Construction & Landscaping
# 12              Doner Restaurant                   Donut Shop
# 13                      Pharmacy         Fast Food Restaurant
# 14                     Drugstore  Eastern European Restaurant
# 15                      Pharmacy              Bubble Tea Shop
# 17                     Drugstore          Dumpling Restaurant
# 18           Japanese Restaurant                   Kids Store
# 19                     Drugstore                Women's Store
# 20             Electronics Store               Discount Store
# 21           Dumpling Restaurant            Electronics Store
# 22          Fast Food Restaurant          Japanese Restaurant
# 23                     Drugstore          Dumpling Restaurant
# 24                       Dog Run             Doner Restaurant
# 25                     Drugstore          Dumpling Restaurant
# 26                    Donut Shop                    Drugstore
# 27                Discount Store           Dim Sum Restaurant
# 28                   Supermarket    Middle Eastern Restaurant
# 29              Doner Restaurant                   Donut Shop
# 30                     Drugstore          Dumpling Restaurant
# ..                           ...                          ...
# 72                    Donut Shop                    Drugstore
# 73           Empanada Restaurant                        Diner
# 74            Falafel Restaurant                  Event Space
# 75                    Restaurant                    Nightclub
# 76                       Brewery                         Park
# 77                   Men's Store                       Bakery
# 78          Caribbean Restaurant                   Restaurant
# 79           Empanada Restaurant                     Dive Bar
# 80           Dumpling Restaurant           Dim Sum Restaurant
# 81              Doner Restaurant                   Donut Shop
# 82            Italian Restaurant                          Bar
# 83                       Dog Run  Eastern European Restaurant
# 84                          Food    South American Restaurant
# 85                Sandwich Place                 Burger Joint
# 86                Sandwich Place             Doner Restaurant
# 87                    Smoke Shop         Fast Food Restaurant
# 88           Fried Chicken Joint                     Pharmacy
# 89                Sandwich Place                      Dog Run
# 90           Empanada Restaurant            Electronics Store
# 91           Dumpling Restaurant                Women's Store
# 92                Discount Store         Fast Food Restaurant
# 94             Electronics Store               Discount Store
# 95           Dumpling Restaurant                      Dog Run
# 96                    Donut Shop                    Drugstore
# 97           Dumpling Restaurant  Eastern European Restaurant
# 98   Eastern European Restaurant          Empanada Restaurant
# 99                      Dive Bar                      Dog Run
# 100                   Donut Shop          Dumpling Restaurant
# 101         Fast Food Restaurant          Empanada Restaurant
# 102                   Donut Shop          Dumpling Restaurant
#
# [100 rows x 16 columns]

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)],
        fill=True,
        fill_color=rainbow[int(cluster)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
